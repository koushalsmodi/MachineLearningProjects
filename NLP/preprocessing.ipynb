# %% [markdown]
# ## Setup

# %%
# Preprocessing pipeline for Twitter datasets; will help for sentiment analysis on tweets

# %%
# !pip install nltk matplotlib
# Out:
# ...
#   Using cached pillow-12.1.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.8 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 28.6 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 23.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 59.5 MB/s  0:00:00
# Using cached pillow-12.1.1-cp311-cp311-macosx_11_0_arm64.whl (4.7 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [matplotlib]8 [matplotlib]
# ...

# %%
import nltk # Natural Language Toolkit: Python library for NLP
from nltk.corpus import twitter_samples # sample Twitter dataset from NLTK library
import matplotlib.pyplot as plt # visualization
import random # generating numbers

# %% [markdown]
# ## Twitter dataset

# %%
# Contains 5000 positive tweets and 5000 negative tweets exactly (balanced dataset)
nltk.download('twitter_samples')
# Out:
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     /Users/koushalsmodi/nltk_data...
# [nltk_data]   Unzipping corpora/twitter_samples.zip.
# True

# %%
# select the set of positive and negative tweets
all_positive_tweets = twitter_samples.strings('positive_tweets.json')
all_negative_tweets = twitter_samples.strings('negative_tweets.json')

# %%
# number and dtype
print(f"Number of Positive Tweets: {len(all_positive_tweets)}")
print(f"Number of Negative Tweets: {len(all_negative_tweets)}")


print(f"The Type of all Positive Tweets: {type(all_positive_tweets)}")
print(f"The Type of a single Positive tweet: {type(all_positive_tweets[0])}")
# Out:
# Number of Positive Tweets: 5000
# Number of Negative Tweets: 5000
# The Type of all Positive Tweets: <class 'list'>
# The Type of a single Positive tweet: <class 'str'>

# %%
fig = plt.figure(figsize= (5,5))

# labels
labels = 'Positive', 'Negative'

# sizes for each slice
sizes = [len(all_positive_tweets), len(all_negative_tweets)]

# declare pie chart where the slices will be ordered and plotted counter-clockwise
plt.pie(sizes, labels = labels, autopct='%1.1f%%', shadow=True, startangle=90)

# equal aspect ratio ensures the pie is drawn as a circle
plt.axis('equal')

plt.show()
