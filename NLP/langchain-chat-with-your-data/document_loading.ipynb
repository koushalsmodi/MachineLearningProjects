# %% [markdown]
# ## Document Loading

# %%
## Retrieval Augmented Generation

# An LLM retrieves contextual documents from an external dataset as part of its execution
# This is useful if we want to ask question about specific documents (eg: videos, PDFs, etc)

# %%
import os
os.environ["PATH"] += ":/opt/homebrew/bin"

# %%
! pip install langchain openai dotenv
# Out:
# Requirement already satisfied: langchain in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (1.2.15)
# Requirement already satisfied: openai in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (2.30.0)
# Requirement already satisfied: dotenv in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (0.9.9)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langchain) (1.2.27)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.5 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langchain) (1.1.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.26)
# Requirement already satisfied: packaging>=23.2.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (0.3.13)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.33.1)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.25.0)
# Requirement already satisfied: anyio in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (4.13.0)
# Requirement already satisfied: certifi in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: idna in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from openai) (0.13.0)
# Requirement already satisfied: sniffio in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from openai) (4.67.3)
# Requirement already satisfied: python-dotenv in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from dotenv) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.6.3)

# %%
import os
import openai
import sys
sys.path.append('../..')

from dotenv import load_dotenv, find_dotenv

_ = load_dotenv(find_dotenv())

openai.api_key  = os.environ['OPENAI_API_KEY']

# %% [markdown]
# ## PDFs

# %%
# Loading PDF transcript from Andrew Ng's famous course CS229 [chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://see.stanford.edu/materials/aimlcs229/transcripts/MachineLearning-Lecture01.pdf]
! pip install pypdf langchain-community
# Out:
# Requirement already satisfied: pypdf in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (6.9.2)
# Requirement already satisfied: langchain-community in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (0.4.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langchain-community) (1.2.27)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langchain-community) (1.0.3)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langchain-community) (2.0.49)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langchain-community) (2.33.1)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langchain-community) (3.13.5)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langchain-community) (9.1.4)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langchain-community) (2.13.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langchain-community) (0.7.26)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langchain-community) (2.4.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.1 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (26.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain-community) (3.1.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: anyio in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.13.0)
# Requirement already satisfied: certifi in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: idna in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.6.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)

# %%
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader("docs/MachineLearning-Lecture01.pdf")

# Each page is a Document. A Document contains (page_content) and (metadata)
pages = loader.load()

# %%
len(pages)
# Out:
# 22

# %%
page = pages[0]

# %%
print(len(page.page_content))
# Out:
# 3098

# %%
print(page.page_content[0:500])
# Out:
# MachineLearning-Lecture01
# Instructor (Andrew Ng): Okay. Good morning. Welcome to CS229, the machine
# learning class. So what I wanna do today is just spend a little time going over the logistics
# of the class, and then we'll start to talk a bit about machine learning.
# By way of introduction, my name's Andrew Ng and I'll be instructor for this class. And so
# I personally work in machine learning, and I've worked on it for about 15 years now, and
# I actually think that machine learning is the

# %%
page.metadata
# Out:
# {'producer': 'Acrobat Distiller 8.1.0 (Windows)',
#  'creator': 'PScript5.dll Version 5.2.2',
#  'creationdate': '2008-07-11T11:25:23-07:00',
#  'author': '',
#  'moddate': '2008-07-11T11:25:23-07:00',
#  'title': '',
#  'source': 'docs/MachineLearning-Lecture01.pdf',
#  'total_pages': 22,
#  'page': 0,
#  'page_label': '1'}

# %% [markdown]
# ## YouTube

# %%
from langchain_community.document_loaders.generic import GenericLoader,  FileSystemBlobLoader
from langchain_community.document_loaders.parsers import OpenAIWhisperParser
from langchain_community.document_loaders.blob_loaders.youtube_audio import YoutubeAudioLoader

# %%
! pip install yt_dlp pydub
# Out:
# Requirement already satisfied: yt_dlp in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (2026.3.17)
# Requirement already satisfied: pydub in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (0.25.1)

# %%
url="https://www.youtube.com/watch?v=jGwO_UgTS7I"
save_dir="docs/youtube/"
loader = GenericLoader(
    YoutubeAudioLoader([url],save_dir),  # fetch from youtube
    #FileSystemBlobLoader(save_dir, glob="*.m4a"),   #fetch locally
    OpenAIWhisperParser()
)
docs = loader.load()
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=jGwO_UgTS7I
# [youtube] jGwO_UgTS7I: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] jGwO_UgTS7I: Downloading android vr player API JSON
# [info] jGwO_UgTS7I: Downloading 1 format(s): 140
# [download] docs/youtube//Stanford CS229： Machine Learning Course, Lecture 1 - Andrew Ng (Autumn 2018).m4a has already been downloaded
# [download] 100% of   69.76MiB
# [ExtractAudio] Not converting audio docs/youtube//Stanford CS229： Machine Learning Course, Lecture 1 - Andrew Ng (Autumn 2018).m4a; file is already in target format m4a
# Transcribing part 1!
# Transcribing part 2!
# Transcribing part 3!
# Transcribing part 4!

# %%
docs[0].page_content[:500]
# Out:
# "Welcome to CS229 Machine Learning. Uh, some of you know that this is a class that's taught at Stanford for a long time. And this is often the class that, um, I most look forward to teaching each year because this is where we've helped, I think, several generations of Stanford students become experts in machine learning, got- built many of their products and services and startups that I'm sure, many of you or probably all of you are using, uh, uh, today. Um, so what I want to do today was spend s"

# %% [markdown]
# ## URLs

# %%
# !pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: beautifulsoup4 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from bs4) (4.14.3)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from beautifulsoup4->bs4) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/.venv/lib/python3.11/site-packages (from beautifulsoup4->bs4) (4.15.0)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader(
    "https://raw.githubusercontent.com/basecamp/handbook/master/titles-for-programmers.md"
)
docs = loader.load()
print(docs[0].page_content[:500])
# Out:
# # Titles for Programmers
#
# ## Programming Management
#
# On Web, SIP, and Mobile programming teams, Lead Programmers (L4) and Principal Programmers (L5) act as tech leads to Junior - Senior Programmers (L1-3). All Principals report directly to our CTO. Tech leads are responsible for:
# - Reviewing a report's substantial PRs before they're shipped.
# - Having a kick-off conversation with a report on every substantial project.
# - Reviewing a report's on-call work and handoff after every shift.
# - Providing

# %% [markdown]
# ## Notion

# %%
# /Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/NLP/langchain-chat-with-your-data/docs/Notion_DB
from langchain_community.document_loaders import NotionDirectoryLoader
loader = NotionDirectoryLoader("docs/Notion_DB")
docs = loader.load()

# %%
print(docs[0].page_content[0:200])
# Out:
# # Sickness absence
#
# ## What to do when someone calls in sick **⛑**
#
# People in your team might call in sick at some point. Here's what to do:
#
# - Make sure they **communicate** it well with the team and

# %%
docs[0].metadata
# Out:
# {'source': 'docs/Notion_DB/Sickness absence d7bf61ffe06f829dbf8c818e90f9bdc6.md'}
