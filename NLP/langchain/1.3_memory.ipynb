# %% [markdown]
# ## Short-Term Memory

# %% [markdown]
# ### No Memory

# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.messages import HumanMessage
from langchain.agents import create_agent

agent = create_agent(
    model = "gpt-5-nano"
)

question = HumanMessage(content = "Hello, my name is Sean and my favorite color is green")

response = agent.invoke({"messages": [question]})

from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello, my name is Sean and my favorite color is green', additional_kwargs={}, response_metadata={}, id='f3b08808-3c2b-4343-b437-e1df80a18afe'),
#               AIMessage(content='Hi Sean! Nice to meet you. Green is a great color—calming and vibrant at the same time. What would you like to chat about today? If you want, I can share green-themed ideas (gardening, interior design, eco-friendly tips) or anything else you’re curious about.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 454, 'prompt_tokens': 18, 'total_tokens': 472, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 384, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DYMSwHdoOuEZCkSXfcq31FpMu1wqB', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019dc255-924a-7ef3-8f86-9f8570480fcf-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 18, 'output_tokens': 454, 'total_tokens': 472, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 384}})]}

# %%
question = HumanMessage(content = "What is my favorite color?")

response = agent.invoke({"messages": [question]})

from pprint import pprint
pprint(response)
# Out:
# {'messages': [HumanMessage(content='What is my favorite color?', additional_kwargs={}, response_metadata={}, id='2b58215c-5e24-4267-b9fb-407a58f340b6'),
#               AIMessage(content='I don’t know your favorite color. I don’t have access to your personal preferences unless you share them. If you’d like, tell me a few colors you like or describe the vibe you want (calm, bold, natural, futuristic), and I’ll suggest a likely favorite. Or I can just guess randomly—want me to pick one?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1040, 'prompt_tokens': 12, 'total_tokens': 1052, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 960, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DYMT1nfjTM5anu0861k87bMGDzwCh', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019dc255-a506-7a02-be96-715d203e284c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 12, 'output_tokens': 1040, 'total_tokens': 1052, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 960}})]}

# %% [markdown]
# ### Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    model = "gpt-5",
    checkpointer=InMemorySaver(),
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Sean and my favorite color is green")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},
    config
)

# %%
question = HumanMessage(content = "What is my favorite color?")

response = agent.invoke({"messages": [question]}, 
                        config)

from pprint import pprint
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Sean and my favorite color is green', additional_kwargs={}, response_metadata={}, id='5c3798a4-57d8-4543-a331-fd67a99e9900'),
#               AIMessage(content='Hi Sean! Nice to meet you. Green is a great choice—do you have a favorite shade? How can I help today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 228, 'prompt_tokens': 17, 'total_tokens': 245, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 192, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DYMZLRhpekomzmHn7FSLQJpHlvnp8', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019dc25b-a23d-7012-b219-1acab2290601-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 17, 'output_tokens': 228, 'total_tokens': 245, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 192}}),
#               HumanMessage(content='What is my favorite color?', additional_kwargs={}, response_metadata={}, id='d329f72a-dc70-4e76-984d-4cb9b87a3596'),
#               AIMessage(content='Your favorite color is green.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 79, 'prompt_tokens': 60, 'total_tokens': 139, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DYMZhnlBcWiS5gKTuBkHHmFkRgTCc', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019dc25b-f8c5-70a3-81d2-f812e0e66f7a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 60, 'output_tokens': 79, 'total_tokens': 139, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}})]}
