# %%
x = 2
x = 4
print(x)
# Out:
# 4

# %%
x = []
x.append(2)
x.append(4)
print(x)
# Out:
# [2, 4]

# %%
carryon = ['socks', 'shoes', 'ties', 'perfume']
print(carryon)
# Out:
# ['socks', 'shoes', 'ties', 'perfume']

# %%
# mixed data types list
mixed = ['bear', 46.5, 29]
print(mixed)
# Out:
# ['bear', 46.5, 29]

# %%
nums = [4, [42, 24], 1]
print(nums)
# Out:
# [4, [42, 24], 1]

# %%
for num in nums:
    print(num)
# Out:
# 4
# [42, 24]
# 1

# %%
carryon = ['socks', 'shoes', 'ties', 'perfume']
print(carryon[2])
# Out:
# ties

# %%
# lists are mutable, strings are immutable
carryon = ['socks', 'shoes', 'ties', 'perfume']
carryon[2] = 'belt'
print(carryon)
# Out:
# ['socks', 'shoes', 'belt', 'perfume']

# %%
len(carryon)
# Out:
# 4

# %%
print(range(len(carryon)))
# Out:
# range(0, 4)

# %%
# concatenating
a = [1,2,3]
b = [4,5, 6]
c = a+b
print(c)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
print(a)
# Out:
# [1, 2, 3]

# %%
# lists slicing
t = [9, 41, 12, 3, 74, 15]
t[1:3]
# Out:
# [41, 12]

# %%
t[:4]
# Out:
# [9, 41, 12, 3]

# %%
t[3:]
# Out:
# [3, 74, 15]

# %%
dir(list())
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
# building a list from scratch
stuff = list()
stuff.append(10.11)
print(stuff)
stuff.append('ball')
print(stuff)
stuff.append(24)
print(stuff)
# Out:
# [10.11]
# [10.11, 'ball']
# [10.11, 'ball', 24]

# %%
10.11 in stuff
# Out:
# True

# %%
'ball' in stuff
# Out:
# True

# %%
24 not in stuff
# Out:
# False

# %%
friends = ['Daniel', 'Elon', 'Alex']
friends.sort()

# %%
print(friends)
# Out:
# ['Alex', 'Daniel', 'Elon']

# %%
t = [9, 41, 12, 3, 74, 15]
min(t)
# Out:
# 3

# %%
max(t)
# Out:
# 74

# %%
sum(t)
# Out:
# 154

# %%
len(t)
# Out:
# 6

# %%
nums = []

while True:
    num = input('Number: ')
    if num == 'done':
        break
    num = int(num)
    nums.append(num)

average = sum(nums) / len(nums)
print('Average', average)
# Out:
# Average 5.666666666666667

# %%
abc = 'Word with spaces'
stuff = abc.split()

# %%
print(stuff)
# Out:
# ['Word', 'with', 'spaces']

# %%
for w in stuff:
    print(w)
# Out:
# Word
# with
# spaces

# %%
fhand = open('/Users/koushalsmodi/Desktop/MachineLearning/MachineLearningProjects/Practice/Python/chp8/mbox-short.txt', 'r')

for line in fhand:
    line = line.rstrip()
    if line.startswith('From '):
        words = line.split()
        email_address = words[1]
        school_domain = email_address.split('@')[1]
        print(school_domain)
# Out:
# uct.ac.za
# media.berkeley.edu
# umich.edu
# iupui.edu
# umich.edu
# iupui.edu
# iupui.edu
# iupui.edu
# umich.edu
# umich.edu
# umich.edu
# umich.edu
# iupui.edu
# umich.edu
# caret.cam.ac.uk
# gmail.com
# uct.ac.za
# uct.ac.za
# uct.ac.za
# uct.ac.za
# uct.ac.za
# media.berkeley.edu
# media.berkeley.edu
# media.berkeley.edu
# iupui.edu
# iupui.edu
# iupui.edu
