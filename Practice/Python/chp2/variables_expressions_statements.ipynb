# %%
print('hello')
# Out:
# hello

# %%
print(123)
# Out:
# 123

# %%
print(49.6)
# Out:
# 49.6

# %%
x = 12.4
y = 14
x = 100

# %%
print(x)
print()
print(y)
# Out:
# 100
#
# 14

# %%
a = 35.0
b = 12.4

c = a*b 
print(c)
# Out:
# 434.0

# %%
hours = 35.0
rate = 12.4

pay = hours*rate

print(pay)
# Out:
# 434.0

# %%
x = 1+2**3/4*5
# Paranthesis, Power, Multiplication/Division, Addition/Subtraction (Left to Right)
print(x)
# Out:
# 11.0

# %%
eee = 'hello ' + 'there'
print(eee)
# Out:
# hello there

# %%
print(type(eee))
# Out:
# <class 'str'>

# %%
eee = eee + 1
print(eee)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 eee = eee + 1
#       2 print(eee)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print(type('hello'))
# Out:
# <class 'str'>

# %%
print(type(1))
# Out:
# <class 'int'>

# %%
y = 1
print(type(y))
# Out:
# <class 'int'>

# %%
z = 42.6
print(type(z))
# Out:
# <class 'float'>

# %%
a = float(y) + 100
print(a)
# Out:
# 101.0

# %%
print(10/2)
# Out:
# 5.0

# %%
print(9/2)
# Out:
# 4.5

# %%
print(10.0/2)
# Out:
# 5.0

# %%
sval = '123'
ival = int(sval)
print(ival)
print()
print(type(ival))
# Out:
# 123
#
# <class 'int'>

# %%
ival+=1
print(ival)
# Out:
# 124

# %%
# User Input
name = input('What"s your name? ')
print('Welcome', name)
# Out:
# Welcome Neeshaa Modii

# %%
inp = int(input('Europe Floor'))
usf = inp+1
print('US Floor:', usf)
# Out:
# US Floor: 1

# %%
file_name = input('Please enter file name: ')
# 'The Mahabharata of Krishna-Dwaipayana Vyasa.txt'
with open(file_name, 'r') as f:
    counts = dict()
    for line in f:
        words = line.split()
        for word in words:
            counts[word] = counts.get(word, 0) + 1
    
    bigWord = None
    bigCount = None
    
    for word, count in counts.items():
        if bigCount is None or count > bigCount:
            bigCount = count
            bigWord = word 
    print('bigCount', bigCount)
    print('bigWord', bigWord)
# Out:
# bigCount 15931
# bigWord the
