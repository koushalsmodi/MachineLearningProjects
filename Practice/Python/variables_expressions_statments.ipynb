# %%
print('hello')
# Out:
# hello

# %%
print(123)
# Out:
# 123

# %%
print(49.6)
# Out:
# 49.6

# %%
x = 12.4
y = 14
x = 100

# %%
print(x)
print()
print(y)
# Out:
# 100
#
# 14

# %%
a = 35.0
b = 12.4

c = a*b 
print(c)
# Out:
# 434.0

# %%
hours = 35.0
rate = 12.4

pay = hours*rate

print(pay)
# Out:
# 434.0
